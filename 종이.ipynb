# %%
1. start ,end 분리해서 시작, 끝 날짜 잡기
2. 요일 표시해놓기 7로나눠서

4.if 문으로 월별 구분해놓기
5. 로그인 데이트 정렬방법

# %%
import datetime

# %%
"02/28SAT"
"02/28"
["02/28"]
0

# %%
"02/28MON"
"02/28"
["02/28"]
1

# %%
"12/22MON"
"12/31"
["12/31","12/29","12/30","12/28","12/26"]
3

# %%
start_date = "05/04MON"
end_date ="06/30"

# %%
login_dates = ["05/26","05/25","05/27","05/10","05/11","05/23","05/22","05/21","05/06","05/09","05/07","05/08","06/25",'06/01']

# %%
def transform(x):
  x_month = int(x[:2])
  x_day = int(x[3:5])
  print(x_month ,  x_day)
  start_num=0
  for i in range(1,x_month):
    if i in month_31:
      start_num+=31
    elif i in month_30:
      start_num+=30
    else:
      start_num+=28
  start_num= start_num+x_day
  return start_num

# %%
start  = transform(start_date)
end  = transform(end_date)
start_yo = start_date[5:]
# Out:
# 5 4
# 6 30

# %%
list_yo = []
if start_yo == "MON":
  list_yo +=["MON","TUE","WED","THU","FRI","SAT","SUN"] 
  list_yo

# %%
start_yo
# Out:
# 'MON'

# %%
end
# Out:
# 181

# %%
start_month = int(start_date[:2])
start_day = int(start_date[3:5])
start_yo = start_date[5:]

# %%
end_month = int(end_date[:2])
end_day = int(end_date[:2])

# %%
start_day
# Out:
# 4

# %%
end_month
# Out:
# 6

# %%
month_31= [1,3,5,7,8,10,12]
month_30 = [4,6,9,11]
month_28 =[2]

# %%
date_transform =[]

# %%
def transform(x):
start_num=0
for i in range(1,start_month):
  if i in month_31:
    start_num+=31
  elif i in month_30:
    start_num+=30
  else:
    start_num+=28
start_num= start_num+start_day

# %%
31 28 31 30

# %%
start_num
# Out:
# 124

# %%
end_num=0
for i in range(1,end_month):
  if i in month_31:
    end_num+=31
  elif i in month_30:
    end_num+=30
  else:
    end_num+=28
end_num= end_num+end_day

# %%
end_num
# Out:
# 157

# %%
def transform(x):
  x_month = int(x[:2])
  x_day = int(x[3:5])
  print(x_month ,  x_day)
  start_num=0
  for i in range(1,x_month):
    if i in month_31:
      start_num+=31
    elif i in month_30:
      start_num+=30
    else:
      start_num+=28
  start_num= start_num+x_day
  return start_num

# %%
a= list(map(transform,login_dates))
a
# Out:
# 5 26
# 5 25
# 5 27
# 5 10
# 5 11
# 5 23
# 5 22
# 5 21
# 5 6
# 5 9
# 5 7
# 5 8
# 6 25
# 6 1
# [146, 145, 147, 130, 131, 143, 142, 141, 126, 129, 127, 128, 176, 152]

# %%
transform("05/26")
# Out:
# 5 5
# 125

# %%
login_dates
# Out:
# ['05/26',
#  '05/25',
#  '05/27',
#  '05/10',
#  '05/11',
#  '05/23',
#  '05/22',
#  '05/21',
#  '05/06',
#  '05/09',
#  '05/07',
#  '05/08',
#  '06/25',
#  '06/01']

# %%
a= list(map(transform,login_dates))
a
# Out:
# [125, 125, 125, 125, 125, 125, 125, 125, 125, 125, 125, 125, 157, 157]

# %%
for i in range(int(start_month),int(end_month)):
  if i in month_31:
    for j in range(int(start_day))
    all_day.append()
   
  elif i in month_30:
  
  else:
# Out:
# 5
# 6

# %%
28 29 30 31 1 2 3 4

# %%
M T

# %%
sorted(login_dates , key = lambda x : (x[:2], x[3:]))
# Out:
# ['05/06',
#  '05/07',
#  '05/08',
#  '05/09',
#  '05/10',
#  '05/11',
#  '05/21',
#  '05/22',
#  '05/23',
#  '05/25',
#  '05/26',
#  '05/27',
#  '06/01',
#  '06/25']

# %%
1. 스타트부터 엔드까지 휴일 표시하기
2. 로그인에서 연속 찾아내기

# %%
연속인거 ,

# %%
9+ 4 + 1 +4

# %%
# 4번

# %%
n= 6

# %%
type1 = 0
for i in range(n):
  type1 += i*i

# %%
type1
# Out:
# 55

# %%
type2 = 0
for j in range(n,0,-2):
  if j == n:
    print('h')
    continue
  type2 += j*j
  print(j)
# Out:
# h
# 4
# 2

# %%
type2
# Out:
# 20

# %%
if n>=4:
  type3 = 0 
  for k in range(n-2):
    type3+= k*k

# %%
type3
# Out:
# 14

# %%
n= 5

# %%
type1 = 0
type2 = 0
type3 = 0 
for i in range(n):
  type1 += i*i
type2 = 0
for j in range(n,0,-2):
  if j == n:
    continue
  type2 += j*j
if n>=4:
  for k in range(n-2):
    type3+= 2*(k*k)
result = type1+ type2+type3

# %%
result
# Out:
# 50

# %%
n=7

# %%
type1 = 0
type2 = 0
for i in range(n):
  type1 += i*i
for j in range(1,n-1):
   type2 += j* (n-j-1)*(n-j-1)
result = type1 + type2

# %%
result
# Out:
# 196

# %%
for j in range(1,n-1):
   h = j* (n-j-1)*(n-j-1)
   print(h)
